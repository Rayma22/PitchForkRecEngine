# %%
import pandas as pd

# %%
pitch = pd.read_csv("pitchfork.csv")

# %%
pitch.columns
pitch.info
# Out:
# <bound method DataFrame.info of                         artist                                       album  \
# 0                  David Byrne  “…The Best Live Show of All Time” — NME EP
# 1                    DJ Healer           Lost Lovesongs / Lostsongs Vol. 2
# 2                  Jorge Velez                                 Roman Birds
# 3                      Chandra                          Transportation EPs
# 4             The Chainsmokers                                    Sick Boy
# ...                        ...                                         ...
# 20868              The Pleased                           Don't Make Things
# 20869             Electric Six                                        Fire
# 20870      Anti-Pop Consortium                   Antipop Vs. Matthew Shipp
# 20871  Damon & Naomi, Kurihara                     Song to the Siren: Live
# 20872           Ben Folds Five                              Ben Folds Live
#
#                  genre  score              date                      author  \
# 0                 Rock    5.5   January 11 2019                   Andy Beta
# 1           Electronic    6.2   January 11 2019                 Chal Ravens
# 2           Electronic    7.9   January 10 2019            Philip Sherburne
# 3                 Rock    7.8   January 10 2019                   Andy Beta
# 4           Electronic    3.1    January 9 2019           Larry Fitzmaurice
# ...                ...    ...               ...                         ...
# 20868             Rock    7.7   October 22 2003            Amanda Petrusich
# 20869  Electronic,Rock    4.0       June 1 2003                   Eric Carr
# 20870   Electronic,Rap    7.2  February 19 2003  Julianne Escobedo Shepherd
# 20871             Rock    4.9   October 28 2002                Ryan Kearney
# 20872             Rock    7.1   October 27 2002                 Rob Mitchum
#
#                       role                                             review  \
# 0              Contributor  Viva Brother, Terris, Mansun, the Twang, Joe L...
# 1              Contributor  The Prince of Denmark—that is, the proper prin...
# 2      Contributing Editor  Jorge Velez has long been prolific, but that’s...
# 3              Contributor  When the Avalanches returned in 2016 after an ...
# 4              Contributor  We’re going to be stuck with the Chainsmokers ...
# ...                    ...                                                ...
# 20868          Contributor  After years of eschewing any label support, Sa...
# 20869          Contributor  "She is so white (white!)/ I was born to excit...
# 20870          Contributor  Matthew Shipp hasn't reached his teeth-baring ...
# 20871                  NaN  Hi kearney_ryan, You've found a sucker! You've...
# 20872          Contributor  The name Ben Folds Five was not, in fact, a go...
#
#        bnm                                               link  \
# 0        0  https://pitchfork.com/reviews/albums/david-byr...
# 1        0  https://pitchfork.com/reviews/albums/dj-healer...
# 2        0  https://pitchfork.com/reviews/albums/jorge-vel...
# 3        0  https://pitchfork.com/reviews/albums/chandra-t...
# 4        0  https://pitchfork.com/reviews/albums/the-chain...
# ...    ...                                                ...
# 20868    0  https://pitchfork.com/reviews/albums/6528-dont...
# 20869    0    https://pitchfork.com/reviews/albums/2733-fire/
# 20870    0  https://pitchfork.com/reviews/albums/208-antip...
# 20871    0  https://pitchfork.com/reviews/albums/2157-song...
# 20872    0  https://pitchfork.com/reviews/albums/3136-ben-...
#
#                       label  release_year
# 0                  Nonesuch        2018.0
# 1             Planet Uterus        2019.0
# 2             Self-released        2019.0
# 3       Telephone Explosion        2018.0
# 4        Disruptor,Columbia        2018.0
# ...                     ...           ...
# 20868  Big Wheel Recreation        2003.0
# 20869                    XL        2003.0
# 20870           Thirsty Ear        2003.0
# 20871               Sub Pop        2002.0
# 20872        Sony 550 Music        2002.0
#
# [20873 rows x 12 columns]>

# %%
pitch.dtypes
# Out:
# artist           object
# album            object
# genre            object
# score           float64
# date             object
# author           object
# role             object
# review           object
# bnm               int64
# link             object
# label            object
# release_year    float64
# dtype: object

# %%
pitch.head()
# Out:
#              artist                                       album       genre  \
# 0       David Byrne  “…The Best Live Show of All Time” — NME EP        Rock
# 1         DJ Healer           Lost Lovesongs / Lostsongs Vol. 2  Electronic
# 2       Jorge Velez                                 Roman Birds  Electronic
# 3           Chandra                          Transportation EPs        Rock
# 4  The Chainsmokers                                    Sick Boy  Electronic
#
#    score             date             author                 role  \
# 0    5.5  January 11 2019          Andy Beta          Contributor
# 1    6.2  January 11 2019        Chal Ravens          Contributor
# 2    7.9  January 10 2019   Philip Sherburne  Contributing Editor
# 3    7.8  January 10 2019          Andy Beta          Contributor
# 4    3.1   January 9 2019  Larry Fitzmaurice          Contributor
#
#                                               review  bnm  \
# 0  Viva Brother, Terris, Mansun, the Twang, Joe L...    0
# 1  The Prince of Denmark—that is, the proper prin...    0
# 2  Jorge Velez has long been prolific, but that’s...    0
# 3  When the Avalanches returned in 2016 after an ...    0
# 4  We’re going to be stuck with the Chainsmokers ...    0
#
#                                                 link                label  \
# 0  https://pitchfork.com/reviews/albums/david-byr...             Nonesuch
# 1  https://pitchfork.com/reviews/albums/dj-healer...        Planet Uterus
# 2  https://pitchfork.com/reviews/albums/jorge-vel...        Self-released
# 3  https://pitchfork.com/reviews/albums/chandra-t...  Telephone Explosion
# 4  https://pitchfork.com/reviews/albums/the-chain...   Disruptor,Columbia
#
#    release_year
# 0        2018.0
# 1        2019.0
# 2        2019.0
# 3        2018.0
# 4        2018.0

# %%
pitch['artist'] = pitch['artist'].str.replace(' ', '').str.lower()

# Displaying the updated DataFrame
pitch.head()
# Out:
#             artist                                       album       genre  \
# 0       davidbyrne  “…The Best Live Show of All Time” — NME EP        Rock
# 1         djhealer           Lost Lovesongs / Lostsongs Vol. 2  Electronic
# 2       jorgevelez                                 Roman Birds  Electronic
# 3          chandra                          Transportation EPs        Rock
# 4  thechainsmokers                                    Sick Boy  Electronic
#
#    score             date             author                 role  \
# 0    5.5  January 11 2019          Andy Beta          Contributor
# 1    6.2  January 11 2019        Chal Ravens          Contributor
# 2    7.9  January 10 2019   Philip Sherburne  Contributing Editor
# 3    7.8  January 10 2019          Andy Beta          Contributor
# 4    3.1   January 9 2019  Larry Fitzmaurice          Contributor
#
#                                               review  bnm  \
# 0  Viva Brother, Terris, Mansun, the Twang, Joe L...    0
# 1  The Prince of Denmark—that is, the proper prin...    0
# 2  Jorge Velez has long been prolific, but that’s...    0
# 3  When the Avalanches returned in 2016 after an ...    0
# 4  We’re going to be stuck with the Chainsmokers ...    0
#
#                                                 link                label  \
# 0  https://pitchfork.com/reviews/albums/david-byr...             Nonesuch
# 1  https://pitchfork.com/reviews/albums/dj-healer...        Planet Uterus
# 2  https://pitchfork.com/reviews/albums/jorge-vel...        Self-released
# 3  https://pitchfork.com/reviews/albums/chandra-t...  Telephone Explosion
# 4  https://pitchfork.com/reviews/albums/the-chain...   Disruptor,Columbia
#
#    release_year
# 0        2018.0
# 1        2019.0
# 2        2019.0
# 3        2018.0
# 4        2018.0

# %%
columns_to_remove = ['album', 'date', 'release_year', 'label', 'link', 'bnm', 'role']
pitch.drop(columns=columns_to_remove, inplace=True)
pitch.head()
# Out:
#             artist       genre  score             author  \
# 0       davidbyrne        Rock    5.5          Andy Beta
# 1         djhealer  Electronic    6.2        Chal Ravens
# 2       jorgevelez  Electronic    7.9   Philip Sherburne
# 3          chandra        Rock    7.8          Andy Beta
# 4  thechainsmokers  Electronic    3.1  Larry Fitzmaurice
#
#                                               review
# 0  Viva Brother, Terris, Mansun, the Twang, Joe L...
# 1  The Prince of Denmark—that is, the proper prin...
# 2  Jorge Velez has long been prolific, but that’s...
# 3  When the Avalanches returned in 2016 after an ...
# 4  We’re going to be stuck with the Chainsmokers ...

# %%
pitch['review'] = pitch['review'].astype(str)

# %%
# Separately aggregating 'score' and 'review', then merging the results
score_agg = pitch.groupby(['artist', 'author'])['score'].mean().reset_index()
review_agg = pitch.groupby(['artist', 'author'])['review'].apply(' '.join).reset_index()
genre_agg = pitch.groupby(['artist', 'author'])['genre'].first().reset_index()

# %%
# Merging the aggregated data
grouped_df = pd.merge(score_agg, review_agg, on=['artist', 'author'])
grouped_df = pd.merge(grouped_df, genre_agg, on=['artist', 'author'])
# Renaming the 'score' column to 'average_score'
grouped_df.rename(columns={'score': 'average_score'}, inplace=True)

# %%
grouped_df.head()
# Out:
#   artist             author  average_score  \
# 0    !!!         Brian Howe       6.933333
# 1    !!!       Cameron Cook       6.900000
# 2    !!!  Larry Fitzmaurice       6.900000
# 3    !!!     Nick Sylvester       7.000000
# 4    !!!      Stuart Berman       7.300000
#
#                                               review genre
# 0  Wandering into North Carolina venue the Cat's ...  Rock
# 1  Despite popular perception, !!! never quite fi...  Rock
# 2  Yup, those big, bold, triple-declaratory excla...  Rock
# 3  For club-friendly artists to become or remain ...  Rock
# 4  It’s either a highly fortuitous coincidence or...  Rock

# %%
grouped_df['artist'].unique()
grouped_df['artist'].nunique()
# Out:
# 9788

# %%
grouped_df['author'].nunique()
# Out:
# 538

# %%
grouped_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17811 entries, 0 to 17810
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   artist         17811 non-null  object
#  1   author         17811 non-null  object
#  2   average_score  17811 non-null  float64
#  3   review         17811 non-null  object
#  4   genre          16157 non-null  object
# dtypes: float64(1), object(4)
# memory usage: 834.9+ KB

# %%
grouped_df.to_csv('aggregated_pitch.csv', index=False)

# %%
from google.colab import files
files.download('aggregated_pitch.csv')

# %%
# df1= pd.read_csv("alternative_music_data.csv")
# df2=  pd.read_csv("blues_music_data.csv")
# df3=  pd.read_csv("hiphop_music_data.csv")
# df4=  pd.read_csv("indie_alt_music_data.csv")
# df5=  pd.read_csv("metal_music_data.csv")
# df6=  pd.read_csv("pop_music_data.csv")
# df7 = pd.read_csv("rock_music_data.csv")

# %%
# spotify_df= pd.concat([df1, df2, df3,df4,df5,df6,df7])
# spotify_df.reset_index(drop=True, inplace=True)

# %%
spotify_df = pd.read_csv("spotify_df.csv")
spotify_df.columns
# Out:
# Index(['artist', 'Track Name', 'Popularity', 'Genres', 'Playlist',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'id', 'uri', 'track_href', 'analysis_url', 'duration_ms',
#        'time_signature'],
#       dtype='object')

# %%
spotify_df = spotify_df.rename(columns={'Artist Name': 'artist'})
spotify_df = spotify_df.rename(columns={'Genres': 'genre'})
spotify_df.columns
spotify_df.info
# Out:
# <bound method DataFrame.info of                         artist  \
# 0                        James
# 1                     grandson
# 2                        Foals
# 3                     Longpigs
# 4                 Beastie Boys
# ...                        ...
# 26747                blink-182
# 26748                  Beloved
# 26749              Saint Louis
# 26750    The Smashing Pumpkins
# 26751  Van Der Graaf Generator
#
#                                               Track Name  Popularity  \
# 0                                                   Laid          66
# 1                                        In Over My Head          60
# 2                                            On The Luna          51
# 3                                               She Said          47
# 4                                              Sure Shot          57
# ...                                                  ...         ...
# 26747                                         I Miss You           0
# 26748                                 Failure On My Lips          37
# 26749                                      Carry Me Away          35
# 26750                                Disarm - Remastered          64
# 26751  A Plague Of Lighthouse Keepers (Medley) - 2005...          29
#
#                                                    genre            Playlist  \
# 0      ['britpop', 'madchester', 'new wave', 'new wav...     Alternative 90s
# 1      ['modern alternative rock', 'modern rock', 'ro...   Alternative Beats
# 2      ['alternative dance', 'indie rock', 'modern al...     Alternative 10s
# 3                         ['britpop', 'sheffield indie']     Alternative 90s
# 4      ['alternative rock', 'east coast hip hop', 'go...     Alternative 90s
# ...                                                  ...                 ...
# 26747             ['pop punk', 'punk', 'socal pop punk']    00s Rock Anthems
# 26748                                                 []       2000s Screamo
# 26749                                                 []          Rocktronic
# 26750  ['alternative metal', 'alternative rock', 'gru...       Rocktail Hour
# 26751  ['art rock', 'experimental', 'jazz fusion', 'n...  Prog Rock Monsters
#
#        danceability  energy  key  loudness  mode  ...  instrumentalness  \
# 0             0.457   0.909    0    -9.451     1  ...          0.000276
# 1             0.582   0.817    0    -6.475     1  ...          0.015800
# 2             0.525   0.976    0    -2.023     1  ...          0.000392
# 3             0.210   0.870    5    -5.985     1  ...          0.000488
# 4             0.692   0.799    1    -7.924     1  ...          0.000000
# ...             ...     ...  ...       ...   ...  ...               ...
# 26747         0.652   0.766   11    -6.481     1  ...          0.000006
# 26748         0.189   0.972    2    -2.834     0  ...          0.009400
# 26749         0.286   0.882    7    -2.362     1  ...          0.040600
# 26750         0.527   0.418    4   -10.205     0  ...          0.781000
# 26751         0.115   0.668    0    -8.363     1  ...          0.000018
#
#        liveness  valence    tempo                      id  \
# 0        0.1350   0.7550  115.998  2CdS3DRqWR5LAhy4hM5X9W
# 1        0.5750   0.6220  155.124  3r0mb1tzAcCNoA8YRXuIhZ
# 2        0.0804   0.8550  138.984  0Sfj5fPqZzCq9o3f1NNphz
# 3        0.1880   0.5170  168.352  5J7l2wE9wxqod7xIP0jyAB
# 4        0.3010   0.5490   97.978  21REQ1bCUWphT2QK3bLWYQ
# ...         ...      ...      ...                     ...
# 26747    0.0739   0.6410  110.011  51fVH5q9apc5HZhWt3G6v9
# 26748    0.2270   0.2140  172.049  7olQs21wmZmKQBuo9liALF
# 26749    0.1070   0.0438  139.584  31uuND03OyPbUXLWCmolwj
# 26750    0.1390   0.2170  129.517  7A8caPxvrT8ZgLvQPPUCcj
# 26751    0.1010   0.0728   74.857  5RYh6KA70fdHJtQElMWIna
#
#                                         uri  \
# 0      spotify:track:2CdS3DRqWR5LAhy4hM5X9W
# 1      spotify:track:3r0mb1tzAcCNoA8YRXuIhZ
# 2      spotify:track:0Sfj5fPqZzCq9o3f1NNphz
# 3      spotify:track:5J7l2wE9wxqod7xIP0jyAB
# 4      spotify:track:21REQ1bCUWphT2QK3bLWYQ
# ...                                     ...
# 26747  spotify:track:51fVH5q9apc5HZhWt3G6v9
# 26748  spotify:track:7olQs21wmZmKQBuo9liALF
# 26749  spotify:track:31uuND03OyPbUXLWCmolwj
# 26750  spotify:track:7A8caPxvrT8ZgLvQPPUCcj
# 26751  spotify:track:5RYh6KA70fdHJtQElMWIna
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/2CdS3DRqWR5L...
# 1      https://api.spotify.com/v1/tracks/3r0mb1tzAcCN...
# 2      https://api.spotify.com/v1/tracks/0Sfj5fPqZzCq...
# 3      https://api.spotify.com/v1/tracks/5J7l2wE9wxqo...
# 4      https://api.spotify.com/v1/tracks/21REQ1bCUWph...
# ...                                                  ...
# 26747  https://api.spotify.com/v1/tracks/51fVH5q9apc5...
# 26748  https://api.spotify.com/v1/tracks/7olQs21wmZmK...
# 26749  https://api.spotify.com/v1/tracks/31uuND03OyPb...
# 26750  https://api.spotify.com/v1/tracks/7A8caPxvrT8Z...
# 26751  https://api.spotify.com/v1/tracks/5RYh6KA70fdH...
#
#                                             analysis_url duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/2CdS...      156667
# 1      https://api.spotify.com/v1/audio-analysis/3r0m...      198366
# 2      https://api.spotify.com/v1/audio-analysis/0Sfj...      192695
# 3      https://api.spotify.com/v1/audio-analysis/5J7l...      264067
# 4      https://api.spotify.com/v1/audio-analysis/21RE...      199667
# ...                                                  ...         ...
# 26747  https://api.spotify.com/v1/audio-analysis/51fV...      227813
# 26748  https://api.spotify.com/v1/audio-analysis/7olQ...      276333
# 26749  https://api.spotify.com/v1/audio-analysis/31uu...      183214
# 26750  https://api.spotify.com/v1/audio-analysis/7A8c...      196905
# 26751  https://api.spotify.com/v1/audio-analysis/5RYh...     1392667
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 26747              4
# 26748              4
# 26749              4
# 26750              4
# 26751              4
#
# [26752 rows x 22 columns]>

# %%
spotify_df.head()
spotify_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26752 entries, 0 to 26751
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist            26752 non-null  object
#  1   Track Name        26752 non-null  object
#  2   Popularity        26752 non-null  int64
#  3   genre             26752 non-null  object
#  4   Playlist          26752 non-null  object
#  5   danceability      26752 non-null  float64
#  6   energy            26752 non-null  float64
#  7   key               26752 non-null  int64
#  8   loudness          26752 non-null  float64
#  9   mode              26752 non-null  int64
#  10  speechiness       26752 non-null  float64
#  11  acousticness      26752 non-null  float64
#  12  instrumentalness  26752 non-null  float64
#  13  liveness          26752 non-null  float64
#  14  valence           26752 non-null  float64
#  15  tempo             26752 non-null  float64
#  16  id                26752 non-null  object
#  17  uri               26752 non-null  object
#  18  track_href        26752 non-null  object
#  19  analysis_url      26752 non-null  object
#  20  duration_ms       26752 non-null  int64
#  21  time_signature    26752 non-null  int64
# dtypes: float64(9), int64(5), object(8)
# memory usage: 4.5+ MB

# %%
# Remove duplicate rows based on 'artist' and 'Track Name' columns
spotify_df_unique = spotify_df.drop_duplicates(subset=['artist', 'Track Name'])

# %%
# Grouping by artist and calculating the mean for the specified features
features_to_average = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
                       'acousticness', 'instrumentalness', 'liveness', 'valence',
                       'tempo', 'duration_ms', 'time_signature']

artist_grouped_df = spotify_df_unique.groupby('artist')[features_to_average].mean().reset_index()
artist_grouped_df['artist'] = artist_grouped_df['artist'].apply(lambda x: x.replace(" ", "").lower())
artist_grouped_df.head()
# Out:
#         artist  danceability  energy  key  loudness  mode  speechiness  \
# 0          !!!         0.858   0.717  0.0   -8.7340   1.0      0.09950
# 1         $not         0.757   0.511  9.5   -8.1355   1.0      0.14625
# 2  $uicideboy$         0.792   0.511  2.0   -6.8760   1.0      0.04090
# 3          '68         0.558   0.977  1.0   -5.0820   1.0      0.21100
# 4  'tiltuesday         0.583   0.574  0.0   -9.0440   1.0      0.02390
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0      0.062600          0.243000    0.2160    0.582  120.004     254920.0
# 1      0.403000          0.169500    0.1925    0.407  137.231     178491.5
# 2      0.124000          0.000090    0.1400    0.111  113.983     168490.0
# 3      0.000618          0.001300    0.3160    0.473  167.984     190031.0
# 4      0.028200          0.000002    0.1140    0.578  104.995     263573.0
#
#    time_signature
# 0             4.0
# 1             4.0
# 2             4.0
# 3             4.0
# 4             4.0

# %%
artist_grouped_df.to_csv('artist_grouped_df.csv', index=False)

# %%
from google.colab import files
files.download('artist_grouped_df.csv')

# %% [markdown]
# merge it based on artist name in common between merge df and pitch fork

# %%
pitch = pd.read_csv("aggregated_pitch.csv")
spotify = pd.read_csv("artist_grouped_df.csv")
spotify.head()
# Out:
#         artist  danceability  energy  key  loudness  mode  speechiness  \
# 0          !!!         0.858   0.717  0.0   -8.7340   1.0      0.09950
# 1         $not         0.757   0.511  9.5   -8.1355   1.0      0.14625
# 2  $uicideboy$         0.792   0.511  2.0   -6.8760   1.0      0.04090
# 3          '68         0.558   0.977  1.0   -5.0820   1.0      0.21100
# 4  'tiltuesday         0.583   0.574  0.0   -9.0440   1.0      0.02390
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0      0.062600          0.243000    0.2160    0.582  120.004     254920.0
# 1      0.403000          0.169500    0.1925    0.407  137.231     178491.5
# 2      0.124000          0.000090    0.1400    0.111  113.983     168490.0
# 3      0.000618          0.001300    0.3160    0.473  167.984     190031.0
# 4      0.028200          0.000002    0.1140    0.578  104.995     263573.0
#
#    time_signature
# 0             4.0
# 1             4.0
# 2             4.0
# 3             4.0
# 4             4.0

# %%
final_merged =  pd.merge(pitch, spotify, on='artist', how='inner')

# %%
final_merged.head()
# Out:
#   artist             author  average_score  \
# 0    !!!         Brian Howe       6.933333
# 1    !!!       Cameron Cook       6.900000
# 2    !!!  Larry Fitzmaurice       6.900000
# 3    !!!     Nick Sylvester       7.000000
# 4    !!!      Stuart Berman       7.300000
#
#                                               review genre  danceability  \
# 0  Wandering into North Carolina venue the Cat's ...  Rock         0.858
# 1  Despite popular perception, !!! never quite fi...  Rock         0.858
# 2  Yup, those big, bold, triple-declaratory excla...  Rock         0.858
# 3  For club-friendly artists to become or remain ...  Rock         0.858
# 4  It’s either a highly fortuitous coincidence or...  Rock         0.858
#
#    energy  key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   0.717  0.0    -8.734   1.0       0.0995        0.0626             0.243
# 1   0.717  0.0    -8.734   1.0       0.0995        0.0626             0.243
# 2   0.717  0.0    -8.734   1.0       0.0995        0.0626             0.243
# 3   0.717  0.0    -8.734   1.0       0.0995        0.0626             0.243
# 4   0.717  0.0    -8.734   1.0       0.0995        0.0626             0.243
#
#    liveness  valence    tempo  duration_ms  time_signature
# 0     0.216    0.582  120.004     254920.0             4.0
# 1     0.216    0.582  120.004     254920.0             4.0
# 2     0.216    0.582  120.004     254920.0             4.0
# 3     0.216    0.582  120.004     254920.0             4.0
# 4     0.216    0.582  120.004     254920.0             4.0

# %%
final_merged.to_csv('final_merged.csv', index=False)

from google.colab import files
files.download('final_merged.csv')
